# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_excel('./titanic.xlsx')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.rename(columns={'survived': 'SURVIVED'}, inplace=True)
data.columns
# Out:
# Index(['SURVIVED', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.drop(columns='class', inplace=True)
data
# Out:
#      SURVIVED  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S    man
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
ddd=pd.Series(['Dog' 'Cat', 'Dog', 'Cat', 'Bat'])

ddd.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data[data.duplicated()]
# Out:
#      SURVIVED  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 47          1       3  female   NaN      0      0   7.7500        Q  woman
# 76          0       3    male   NaN      0      0   7.8958        S    man
# 77          0       3    male   NaN      0      0   8.0500        S    man
# 87          0       3    male   NaN      0      0   8.0500        S    man
# 95          0       3    male   NaN      0      0   8.0500        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 870         0       3    male  26.0      0      0   7.8958        S    man
# 877         0       3    male  19.0      0      0   7.8958        S    man
# 878         0       3    male   NaN      0      0   7.8958        S    man
# 884         0       3    male  25.0      0      0   7.0500        S    man
# 886         0       2    male  27.0      0      0  13.0000        S    man
#
#      adult_male deck  embark_town alive  alone
# 47        False  NaN   Queenstown   yes   True
# 76         True  NaN  Southampton    no   True
# 77         True  NaN  Southampton    no   True
# 87         True  NaN  Southampton    no   True
# 95         True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 870        True  NaN  Southampton    no   True
# 877        True  NaN  Southampton    no   True
# 878        True  NaN  Southampton    no   True
# 884        True  NaN  Southampton    no   True
# 886        True  NaN  Southampton    no   True
#
# [107 rows x 14 columns]

# %%
data
# Out:
#      SURVIVED  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S    man
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull()
# Out:
#      SURVIVED  pclass    sex    age  sibsp  parch   fare  embarked    who  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#      adult_male   deck  embark_town  alive  alone
# 0         False   True        False  False  False
# 1         False  False        False  False  False
# 2         False   True        False  False  False
# 3         False  False        False  False  False
# 4         False   True        False  False  False
# ..          ...    ...          ...    ...    ...
# 886       False   True        False  False  False
# 887       False  False        False  False  False
# 888       False   True        False  False  False
# 889       False  False        False  False  False
# 890       False   True        False  False  False
#
# [891 rows x 14 columns]

# %%
data.isnull()
# Out:
#      SURVIVED  pclass    sex    age  sibsp  parch   fare  embarked    who  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 885     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#      adult_male   deck  embark_town  alive  alone
# 0         False   True        False  False  False
# 1         False  False        False  False  False
# 2         False   True        False  False  False
# 3         False  False        False  False  False
# 4         False   True        False  False  False
# ..          ...    ...          ...    ...    ...
# 885       False   True        False  False  False
# 887       False  False        False  False  False
# 888       False   True        False  False  False
# 889       False  False        False  False  False
# 890       False   True        False  False  False
#
# [784 rows x 14 columns]

# %%
data.isnull().head(10)
# Out:
#    SURVIVED  pclass    sex    age  sibsp  parch   fare  embarked    who  \
# 0     False   False  False  False  False  False  False     False  False
# 1     False   False  False  False  False  False  False     False  False
# 2     False   False  False  False  False  False  False     False  False
# 3     False   False  False  False  False  False  False     False  False
# 4     False   False  False  False  False  False  False     False  False
# 5     False   False  False   True  False  False  False     False  False
# 6     False   False  False  False  False  False  False     False  False
# 7     False   False  False  False  False  False  False     False  False
# 8     False   False  False  False  False  False  False     False  False
# 9     False   False  False  False  False  False  False     False  False
#
#    adult_male   deck  embark_town  alive  alone
# 0       False   True        False  False  False
# 1       False  False        False  False  False
# 2       False   True        False  False  False
# 3       False  False        False  False  False
# 4       False   True        False  False  False
# 5       False   True        False  False  False
# 6       False  False        False  False  False
# 7       False   True        False  False  False
# 8       False   True        False  False  False
# 9       False   True        False  False  False

# %%
data.isnull().sum()
# Out:
# SURVIVED         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# SURVIVED       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
data.dropna(axis=1)
# Out:
#      SURVIVED  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 6           0       1    male  54.0      0      0  51.8625        S    man
# 10          1       3  female   4.0      1      1  16.7000        S  child
# 11          1       1  female  58.0      0      0  26.5500        S  woman
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  woman
# 872         0       1    male  33.0      0      0   5.0000        S    man
# 879         1       1  female  56.0      0      1  83.1583        C  woman
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
#
#      adult_male deck  embark_town alive  alone
# 1         False    C    Cherbourg   yes  False
# 3         False    C  Southampton   yes  False
# 6          True    E  Southampton    no   True
# 10        False    G  Southampton   yes  False
# 11        False    C  Southampton   yes   True
# ..          ...  ...          ...   ...    ...
# 871       False    D  Southampton   yes  False
# 872        True    B  Southampton    no   True
# 879       False    C    Cherbourg   yes  False
# 887       False    B  Southampton   yes   True
# 889        True    C    Cherbourg   yes   True
#
# [181 rows x 14 columns]

# %%
data['age'].fillna(data['age'].mean(), inplace=True)

# %%
data.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      SURVIVED  pclass    sex    age  sibsp  parch   fare  embarked    who  \
# 1       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 6       False   False  False  False  False  False  False     False  False
# 10      False   False  False  False  False  False  False     False  False
# 11      False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 871     False   False  False  False  False  False  False     False  False
# 872     False   False  False  False  False  False  False     False  False
# 879     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
#
#      adult_male   deck  embark_town  alive  alone
# 1         False  False        False  False  False
# 3         False  False        False  False  False
# 6         False  False        False  False  False
# 10        False  False        False  False  False
# 11        False  False        False  False  False
# ..          ...    ...          ...    ...    ...
# 871       False  False        False  False  False
# 872       False  False        False  False  False
# 879       False  False        False  False  False
# 887       False  False        False  False  False
# 889       False  False        False  False  False
#
# [181 rows x 14 columns]>

# %%
ddd=pd.Series([4, 5, 6, 7, 8, 9])

ddd.replace(4, 10)
# Out:
# 0    10
# 1     5
# 2     6
# 3     7
# 4     8
# 5     9
# dtype: int64

# %%
dpd = pd.DataFrame({'X':[0, 1, 2, 3, 4, 5],
                    'Y':[6, 7, 8, 9, 10 ,11],
                    'Z':['a', 'b', 'c', 'd', 'e', 'f']})

# %%
dpd
# Out:
#    X   Y  Z
# 0  0   6  a
# 1  1   7  b
# 2  2   8  c
# 3  3   9  d
# 4  4  10  e
# 5  5  11  f

# %%
dpd.replace(0, 11)
# Out:
#     X   Y  Z
# 0  11   6  a
# 1   1   7  b
# 2   2   8  c
# 3   3   9  d
# 4   4  10  e
# 5   5  11  f

# %%
dd1=dpd.replace(0, 11)

# %%
dd1.replace(11, 40)
# Out:
#     X   Y  Z
# 0  40   6  a
# 1   1   7  b
# 2   2   8  c
# 3   3   9  d
# 4   4  10  e
# 5   5  40  f

# %%
data.replace({'sex': {'male': 0}}, inplace=True)
data
# Out:
#      SURVIVED  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 6           0       1       0  54.0      0      0  51.8625        S    man
# 10          1       3  female   4.0      1      1  16.7000        S  child
# 11          1       1  female  58.0      0      0  26.5500        S  woman
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  woman
# 872         0       1       0  33.0      0      0   5.0000        S    man
# 879         1       1  female  56.0      0      1  83.1583        C  woman
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 889         1       1       0  26.0      0      0  30.0000        C    man
#
#      adult_male deck  embark_town alive  alone
# 1         False    C    Cherbourg   yes  False
# 3         False    C  Southampton   yes  False
# 6          True    E  Southampton    no   True
# 10        False    G  Southampton   yes  False
# 11        False    C  Southampton   yes   True
# ..          ...  ...          ...   ...    ...
# 871       False    D  Southampton   yes  False
# 872        True    B  Southampton    no   True
# 879       False    C    Cherbourg   yes  False
# 887       False    B  Southampton   yes   True
# 889        True    C    Cherbourg   yes   True
#
# [181 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['who_labeled'] = le.fit_transform(data.who)

data
# Out:
#      SURVIVED  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 6           0       1       0  54.0      0      0  51.8625        S    man
# 10          1       3  female   4.0      1      1  16.7000        S  child
# 11          1       1  female  58.0      0      0  26.5500        S  woman
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  woman
# 872         0       1       0  33.0      0      0   5.0000        S    man
# 879         1       1  female  56.0      0      1  83.1583        C  woman
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 889         1       1       0  26.0      0      0  30.0000        C    man
#
#      adult_male deck  embark_town alive  alone  who_labeled
# 1         False    C    Cherbourg   yes  False            2
# 3         False    C  Southampton   yes  False            2
# 6          True    E  Southampton    no   True            1
# 10        False    G  Southampton   yes  False            0
# 11        False    C  Southampton   yes   True            2
# ..          ...  ...          ...   ...    ...          ...
# 871       False    D  Southampton   yes  False            2
# 872        True    B  Southampton    no   True            1
# 879       False    C    Cherbourg   yes  False            2
# 887       False    B  Southampton   yes   True            2
# 889        True    C    Cherbourg   yes   True            1
#
# [181 rows x 15 columns]

# %%
data.describe()
# Out:
#          SURVIVED      pclass         age       sibsp       parch        fare  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     0.674033    1.193370   35.687403    0.469613    0.480663   78.972883
# std      0.470035    0.517644   15.691057    0.645854    0.757123   76.699584
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   48.000000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200
#
#        who_labeled
# count   181.000000
# mean      1.375691
# std       0.616680
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %%
# from sklearn.preprocessing import MinMaxSacler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data[['fare']]=scaler.fit_transform(data[['fare']])

data.describe()
# Out:
#          SURVIVED      pclass         age       sibsp       parch        fare  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     0.674033    1.193370   35.687403    0.469613    0.480663    0.154145
# std      0.470035    0.517644   15.691057    0.645854    0.757123    0.149708
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000    0.057971
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000    0.111257
# 75%      1.000000    1.000000   48.000000    1.000000    1.000000    0.175668
# max      1.000000    3.000000   80.000000    3.000000    4.000000    1.000000
#
#        who_labeled
# count   181.000000
# mean      1.375691
# std       0.616680
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %%
scaler = MinMaxScaler()
data[['fare']]=scaler.fit_transform(data[['fare']])
data.describe()
# Out:
#          SURVIVED      pclass         age       sibsp       parch        fare  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     0.674033    1.193370   35.687403    0.469613    0.480663    0.154145
# std      0.470035    0.517644   15.691057    0.645854    0.757123    0.149708
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000    0.057971
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000    0.111257
# 75%      1.000000    1.000000   48.000000    1.000000    1.000000    0.175668
# max      1.000000    3.000000   80.000000    3.000000    4.000000    1.000000
#
#        who_labeled
# count   181.000000
# mean      1.375691
# std       0.616680
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
# scaler.fit_transform(data)

# %%
data['fare'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data.drop(data[data.fare >= 1].index, inplace = True)
data['fare'].plot(kind="box")
# Out:
# <AxesSubplot:>
